# %%
import xml.etree.ElementTree as ET
import collections
import pandas as pd

# %%
xml_file = "full database.xml"
tree = ET.parse(xml_file)

# %%
root = tree.getroot()

# %%
ns = '{http://www.drugbank.ca}'

# %%
def collapse_list_values(row):
    for key, value in row.items():
        if isinstance(value, list):
            row[key] = '|'.join(value)
    return row

# %%
rows = list()
for i, drug in enumerate(root):
    row = collections.OrderedDict()
    assert drug.tag == ns + 'drug'
    row['type'] = drug.get('type')
    row['drugbank_id'] = drug.findtext(ns + "drugbank-id[@primary='true']")
    row['name'] = drug.findtext(ns + "name").lower()
    row['groups'] = [group.text for group in
        drug.findall("{ns}groups/{ns}group".format(ns = ns))]
    row['indication'] = drug.findtext(ns + "indication")
    row['patents'] = sorted({group.text for group in
        drug.findall("{ns}patents/{ns}patent/{ns}number".format(ns = ns))})
    row['target'] = [group.text for group in
        drug.findall("{ns}targets/{ns}target/{ns}name".format(ns = ns))]
    row['categories'] = [x.findtext(ns + 'category') for x in
        drug.findall("{ns}categories/{ns}category".format(ns = ns))]
    aliases = {
        elem.text for elem in 
        drug.findall("{ns}products/{ns}product/{ns}name".format(ns = ns))
    }
    aliases.add(row['name'])
    row['products'] = sorted(aliases)
    rows.append(row)

# %%
rows = list(map(collapse_list_values, rows))
drugbank_df = pd.DataFrame.from_dict(rows)
drugbank_df.to_csv("drugbank.csv", sep='\t', index=False)

# %%
"2065150|5196404|7582727|7598343".split("|")
# Out:
# ['2065150', '5196404', '7582727', '7598343']

# %%
drugbank_df[drugbank_df.type == "small molecule"]
# Out:
#                  type drugbank_id  \
# 5      small molecule     DB00006
# 13     small molecule     DB00014
# 25     small molecule     DB00027
# 33     small molecule     DB00035
# 47     small molecule     DB00050
# 63     small molecule     DB00067
# 74     small molecule     DB00080
# 84     small molecule     DB00091
# 86     small molecule     DB00093
# 95     small molecule     DB00104
# 97     small molecule     DB00106
# 105    small molecule     DB00114
# 106    small molecule     DB00115
# 107    small molecule     DB00116
# 108    small molecule     DB00117
# 109    small molecule     DB00118
# 110    small molecule     DB00119
# 111    small molecule     DB00120
# 112    small molecule     DB00121
# 113    small molecule     DB00122
# 114    small molecule     DB00123
# 115    small molecule     DB00125
# 116    small molecule     DB00126
# 117    small molecule     DB00127
# 118    small molecule     DB00128
# 119    small molecule     DB00129
# 120    small molecule     DB00130
# 121    small molecule     DB00131
# 122    small molecule     DB00132
# 123    small molecule     DB00133
# ...               ...         ...
# 11870  small molecule     DB14678
# 11871  small molecule     DB14679
# 11872  small molecule     DB14680
# 11873  small molecule     DB14681
# 11874  small molecule     DB14682
# 11875  small molecule     DB14683
# 11876  small molecule     DB14684
# 11887  small molecule     DB14695
# 11893  small molecule     DB14701
# 11894  small molecule     DB14702
# 11895  small molecule     DB14703
# 11896  small molecule     DB14704
# 11897  small molecule     DB14705
# 11898  small molecule     DB14706
# 11900  small molecule     DB14708
# 11906  small molecule     DB14714
# 11907  small molecule     DB14715
# 11908  small molecule     DB14716
# 11909  small molecule     DB14717
# 11910  small molecule     DB14718
# 11911  small molecule     DB14719
# 11912  small molecule     DB14720
# 11913  small molecule     DB14721
# 11914  small molecule     DB14722
# 11915  small molecule     DB14723
# 11917  small molecule     DB14725
# 11918  small molecule     DB14726
# 11919  small molecule     DB14727
# 11920  small molecule     DB14728
# 11921  small molecule     DB14729
#
#                                                     name  \
# 5                                            bivalirudin
# 13                                             goserelin
# 25                                          gramicidin d
# 33                                          desmopressin
# 47                                            cetrorelix
# 63                                           vasopressin
# 74                                            daptomycin
# 84                                           ciclosporin
# 86                                           felypressin
# 95                                            octreotide
# 97                                              abarelix
# 105                                  pyridoxal phosphate
# 106                                       cyanocobalamin
# 107                                 tetrahydrofolic acid
# 108                                            histidine
# 109                                         ademetionine
# 110                                         pyruvic acid
# 111                                      l-phenylalanine
# 112                                               biotin
# 113                                              choline
# 114                                             l-lysine
# 115                                           l-arginine
# 116                                        ascorbic acid
# 117                                             spermine
# 118                                      l-aspartic acid
# 119                                            ornithine
# 120                                          l-glutamine
# 121                                  adenosine phosphate
# 122                                 alpha-linolenic acid
# 123                                               serine
# ...                                                  ...
# 11870                            norethindrone enanthate
# 11871                               quingestanol acetate
# 11872                                  combretastatin a4
# 11873                                          cortisone
# 11874                                        dextrorphan
# 11875                                   prezatide copper
# 11876                              calcium polycarbophil
# 11887                                ferric oxyhydroxide
# 11893  ethyl 8-hydroxy-alpha-(2-propynylamino)-5-quin...
# 11894                                sodium metavanadate
# 11895                    dexamethasone metasulfobenzoate
# 11896                                            ribitol
# 11897                                        ceramide ap
# 11898                                        ceramide ng
# 11900                                    tosylchloramide
# 11906                                       tenivastatin
# 11907                                          cinazepam
# 11908                                         clonazolam
# 11909                                         nitrazolam
# 11910                                          pyrazolam
# 11911                                         bentazepam
# 11912                                        brovanexine
# 11913                                            mk-1454
# 11914                                           adu-s100
# 11915                                      larotrectinib
# 11917                                 cefamandole nafate
# 11918                                         dabigatran
# 11919                           riboflavin tetrabutyrate
# 11920                                            mebenil
# 11921                                       rebeccamycin
#
#                                        groups  \
# 5                    approved|investigational
# 13                                   approved
# 25                                   approved
# 33                                   approved
# 47                   approved|investigational
# 63                                   approved
# 74                   approved|investigational
# 84      approved|investigational|vet_approved
# 86                               experimental
# 95                   approved|investigational
# 97         approved|investigational|withdrawn
# 105    approved|investigational|nutraceutical
# 106                    approved|nutraceutical
# 107                             nutraceutical
# 108                    approved|nutraceutical
# 109    approved|investigational|nutraceutical
# 110    approved|investigational|nutraceutical
# 111    approved|investigational|nutraceutical
# 112    approved|investigational|nutraceutical
# 113                    approved|nutraceutical
# 114                    approved|nutraceutical
# 115                    approved|nutraceutical
# 116                    approved|nutraceutical
# 117                experimental|nutraceutical
# 118                    approved|nutraceutical
# 119                    approved|nutraceutical
# 120    approved|investigational|nutraceutical
# 121    approved|investigational|nutraceutical
# 122                    approved|nutraceutical
# 123                    approved|nutraceutical
# ...                                       ...
# 11870                            experimental
# 11871                            experimental
# 11872                            experimental
# 11873                            experimental
# 11874                            experimental
# 11875                            experimental
# 11876                                approved
# 11887                   approved|experimental
# 11893                            experimental
# 11894                   approved|experimental
# 11895                   approved|experimental
# 11896                            experimental
# 11897                            experimental
# 11898                            experimental
# 11900                            experimental
# 11906                            experimental
# 11907                            experimental
# 11908                            experimental
# 11909                            experimental
# 11910                            experimental
# 11911                            experimental
# 11912                            experimental
# 11913                         investigational
# 11914                         investigational
# 11915                                approved
# 11917                                approved
# 11918                         investigational
# 11919                            experimental
# 11920                            experimental
# 11921                            experimental
#
#                                               indication  \
# 5      For treatment of heparin-induced thrombocytope...
# 13     Used to treat hormone-sensitive cancers of the...
# 25     For treatment of skin lesions, surface wounds ...
# 33     - Indicated for the treatment of nocturia due ...
# 47     For the inhibition of premature LH surges in w...
# 63     For the treatment of enuresis, polyuria, diabe...
# 74     For the treatment of complicated skin and skin...
# 84     For treatment of transplant (kidney, liver, an...
# 86     For use as an alternative to adrenaline as a l...
# 95     For treatment of acromegaly and reduction of s...
# 97     For palliative treatment of advanced prostate ...
# 105    For nutritional supplementation and for treati...
# 106    For treatment of pernicious anemia (due to lac...
# 107    For nutritional supplementation, also for trea...
# 108    The actions of supplemental L-histidine are en...
# 109    S-Adenosylmethionine (SAMe) is used as a drug ...
# 110    For nutritional supplementation, also for trea...
# 111    L-phenylalanine may be helpful in some with de...
# 112    For nutritional supplementation, also for trea...
# 113    For nutritional supplementation, also for trea...
# 114    Supplemental L-lysine has putative anti-herpes...
# 115    Used for nutritional supplementation, also for...
# 116    Used to treat vitamin C deficiency, scurvy, de...
# 117    For nutritional supplementation, also for trea...
# 118    There is no support for the claim that asparta...
# 119    Used for nutritional supplementation, also for...
# 120    Used for nutritional supplementation, also for...
# 121    For nutritional supplementation, also for trea...
# 122    For nutritional supplementation and for treati...
# 123    Used as a natural moisturizing agent in some c...
# ...                                                  ...
# 11870
# 11871
# 11872
# 11873
# 11874
# 11875  Commonly used in cosmetic products for the ski...
# 11876  Polycarbophil is used to treat constipation an...
# 11887
# 11893
# 11894
# 11895
# 11896
# 11897
# 11898
# 11900
# 11906
# 11907
# 11908
# 11909
# 11910
# 11911
# 11912
# 11913
# 11914
# 11915  Larotrectinib is a tyrosine kinase inhibitor t...
# 11917
# 11918
# 11919
# 11920
# 11921
#
#                                                  patents  \
# 5                        2065150|5196404|7582727|7598343
# 13                               7118552|7220247|7500964
# 25
# 33     2484724|2486833|5500413|7022340|7405203|756042...
# 47                               2115943|5198533|6319192
# 63       9375478|9687526|9744209|9744239|9750785|9937223
# 74     2344318|6468967|6852689|8003673|8058238|812934...
# 84     1332150|2108018|4839342|5985321|8292129|856185...
# 86
# 95     1328402|5538739|5728396|5753618|5922338|592268...
# 97               5843901|5968895|6180608|6423686|6699833
# 105
# 106      7229636|7404489|7879349|8003353|8940714|9415007
# 107
# 108
# 109
# 110
# 111
# 112
# 113
# 114
# 115
# 116    10016504|7169381|7658914|8999313|9326969|95922...
# 117
# 118
# 119
# 120                                              5288703
# 121
# 122
# 123
# ...                                                  ...
# 11870
# 11871
# 11872
# 11873
# 11874
# 11875
# 11876
# 11887                                    6174442|9561251
# 11893
# 11894
# 11895
# 11896
# 11897
# 11898
# 11900
# 11906
# 11907
# 11908
# 11909
# 11910
# 11911
# 11912
# 11913
# 11914
# 11915
# 11917
# 11918
# 11919
# 11920
# 11921
#
#                                                   target  \
# 5                                            Prothrombin
# 13     Lutropin-choriogonadotropic hormone receptor|G...
# 25
# 33     Vasopressin V2 receptor|Vasopressin V1a recept...
# 47     Gonadotropin-releasing hormone receptor|Lutrop...
# 63     Vasopressin V2 receptor|Vasopressin V1a recept...
# 74     Bacterial outer membrane|Lipoteichoic acid syn...
# 84     Calcium signal-modulating cyclophilin ligand|C...
# 86                              Vasopressin V1a receptor
# 95     Somatostatin receptor type 1|Somatostatin rece...
# 97               Gonadotropin-releasing hormone receptor
# 105    Alanine--glyoxylate aminotransferase 2, mitoch...
# 106    Methionine synthase|Methylmalonyl-CoA mutase, ...
# 107    C-1-tetrahydrofolate synthase, cytoplasmic|Bif...
# 108    Histidine decarboxylase|Histidine--tRNA ligase...
# 109    Glycine N-methyltransferase|S-adenosylmethioni...
# 110    Monocarboxylate transporter 4|Monocarboxylate ...
# 111    Tyrosine aminotransferase|Large neutral amino ...
# 112    Propionyl-CoA carboxylase beta chain, mitochon...
# 113    Choline-phosphate cytidylyltransferase B|Acety...
# 114    High affinity cationic amino acid transporter ...
# 115    Nitric oxide synthase, endothelial|Cationic am...
# 116    Lactase-phlorizin hydrolase|Hyaluronate lyase|...
# 117    Spermine synthase|Spermine oxidase|DNA|Ornithi...
# 118    Ribonuclease pancreatic|Lysozyme C|Calcium-bin...
# 119    Ornithine aminotransferase, mitochondrial|Orni...
# 120    CTP synthase 1|Amidophosphoribosyltransferase|...
# 121    Cyclic AMP-responsive element-binding protein ...
# 122    Fatty acid desaturase 1|Fatty acid desaturase ...
# 123    Cystathionine beta-synthase|L-serine dehydrata...
# ...                                                  ...
# 11870
# 11871
# 11872
# 11873
# 11874
# 11875
# 11876
# 11887
# 11893
# 11894
# 11895
# 11896
# 11897
# 11898
# 11900
# 11906
# 11907
# 11908
# 11909
# 11910
# 11911
# 11912
# 11913
# 11914
# 11915  High affinity nerve growth factor receptor|BDN...
# 11917
# 11918
# 11919
# 11920
# 11921
#
#                                               categories  \
# 5      Amino Acids, Peptides, and Proteins|Anticoagul...
# 13     Adrenal Cortex Hormones|Amino Acids, Peptides,...
# 25     Amino Acids, Peptides, and Proteins|Anti-Bacte...
# 33     Agents that produce hypertension|Amino Acids, ...
# 47     Amino Acids, Peptides, and Proteins|Anti-Gonad...
# 63     Amino Acids, Peptides, and Proteins|Antidiuret...
# 74     Amino Acids, Peptides, and Proteins|Anti-Bacte...
# 84     Agents causing hyperkalemia|Agents that produc...
# 86     Amino Acids, Peptides, and Proteins|Cardiovasc...
# 95     Amino Acids, Peptides, and Proteins|Antineopla...
# 97     Amino Acids, Peptides, and Proteins|Antineopla...
# 105    Alimentary Tract and Metabolism|Coenzymes|Diet...
# 106    Antianemic Preparations|Blood and Blood Formin...
# 107    Biological Factors|Coenzymes|Dietary Supplemen...
# 108    Amino Acids|Amino Acids, Cyclic|Amino Acids, E...
# 109    Adenosine|Alimentary Tract and Metabolism|Amin...
# 110    Dietary Supplements|Keto Acids|Pyruvates|Suppl...
# 111    Amino Acids|Amino Acids, Aromatic|Amino Acids,...
# 112    Alimentary Tract and Metabolism|Coenzymes|Diet...
# 113    Alcohols|Amines|Amino Alcohols|Ammonium Compou...
# 114    Amino Acids|Amino Acids, Basic|Amino Acids, Di...
# 115    Amino Acids|Amino Acids, Basic|Amino Acids, Di...
# 116    Acids, Acyclic|Alimentary Tract and Metabolism...
# 117    Amines|Biogenic Amines|Biogenic Polyamines|Dia...
# 118    Amino Acids|Amino Acids, Acidic|Amino Acids, D...
# 119    Alimentary Tract and Metabolism|Amino Acids|Am...
# 120    Alimentary Tract and Metabolism|Amino Acids|Am...
# 121    Adenine Nucleotides|Carbohydrates|Dietary Supp...
# 122    Diet, Food, and Nutrition|Dietary Fats|Dietary...
# 123    Amino Acids|Amino Acids, Neutral|Amino Acids, ...
# ...                                                  ...
# 11870  Adrenal Cortex Hormones|Contraceptive Agents, ...
# 11871  Adrenal Cortex Hormones|Norpregnanes|Norsteroi...
# 11872  Antineoplastic Agents|Antineoplastic Agents, P...
# 11873  Adrenal Cortex Hormones|Corticosteroid Hormone...
# 11874  Alkaloids|Central Nervous System Agents|Excita...
# 11875  Amino Acids, Peptides, and Proteins|Growth Sub...
# 11876  Alimentary Tract and Metabolism|Antidiarrheals...
# 11887  Iron Compounds|Organometallic Compounds|Phosph...
# 11893
# 11894        Anions|Electrolytes|Ions|Vanadium Compounds
# 11895  Pregnadienes|Pregnadienetriols|Pregnanes|Stero...
# 11896              Alcohols|Carbohydrates|Sugar Alcohols
# 11897  Amides|Carbohydrates|Glycoconjugates|Glycolipi...
# 11898  Amides|Carbohydrates|Glycoconjugates|Glycolipi...
# 11900  Amides|Anti-Infective Agents|Anti-Infective Ag...
# 11906
# 11907  Benzazepines|Benzodiazepines and benzodiazepin...
# 11908
# 11909
# 11910
# 11911  Central Nervous System Agents|Central Nervous ...
# 11912  Acids, Carbocyclic|Amides|Benzene Derivatives|...
# 11913
# 11914
# 11915  BCRP/ABCG2 Substrates|Cytochrome P-450 CYP3A S...
# 11917  Amides|Anti-Bacterial Agents|Anti-Infective Ag...
# 11918  Anticoagulants|Antithrombins|Benzimidazoles|En...
# 11919  Biological Factors|Coenzymes|Enzymes and Coenz...
# 11920                                             Amides
# 11921                                            Indoles
#
#                                                 products
# 5      Angiomax|Bivalirudin|Bivalirudin for Injection...
# 13                          Zoladex|Zoladex LA|goserelin
# 25     Antibiotic Cream|Antibiotic Cream Plus Pain Re...
# 33     DDAVP Rhinal Tube|Ddavp|Ddavp Inj 4mcg/ml|Ddav...
# 47                                  Cetrotide|cetrorelix
# 63     Pitressin|Pitressin Inj 10 Unit/0.5ml|Pressyn ...
# 74              Cubicin|Cubicin RF|Daptomycin|daptomycin
# 84     Apo-cyclosporine Oral Solution|Aqua-stasis|Ceq...
# 86                                           felypressin
# 95     Ocphyl|Octreotide|Octreotide Acetate|Octreotid...
# 97                                              abarelix
# 105    BumP DHA|Dyzbac|EnBrace HR|EnLyte|L-Methyl-B6-...
# 106    24 Multivitamins + Minerals|50 Plus|50 Plus Mu...
# 107                                 tetrahydrofolic acid
# 108    2.5% Travasol Amino Acid Injection With Electr...
# 109                                         ademetionine
# 110                               Rejuvesol|pyruvic acid
# 111    2.5% Travasol Amino Acid Injection With Electr...
# 112    24 Multivitamins + Minerals|50 Plus|50 Plus Mu...
# 113    24 Multivitamins + Minerals|50 Plus|Advanced 2...
# 114    2.5% Travasol Amino Acid Injection With Electr...
# 115    2.5% Travasol Amino Acid Injection With Electr...
# 116    24 Multivitamins + Minerals|50 Plus|50 Plus Mu...
# 117                                             spermine
# 118    20% Prosol|Aminosyn II|Aminosyn II 10% With El...
# 119             Primene 10%|Primene 10%-liq IV|ornithine
# 120                        Endari|NutreStore|l-glutamine
# 121                                  adenosine phosphate
# 122    Bio-efa Borage Gla 90 Cap|Cavan One|Flaxseed O...
# 123    2.5% Travasol Amino Acid Injection With Electr...
# ...                                                  ...
# 11870                            norethindrone enanthate
# 11871                               quingestanol acetate
# 11872                                  combretastatin a4
# 11873                                          cortisone
# 11874                                        dextrorphan
# 11875  Cosmeceutical Mask Pack|Dermaheal Cosmeceutica...
# 11876  Calcium Polycarbophil 625 mg|Care One Fiber|Eq...
# 11887                       Velphoro|ferric oxyhydroxide
# 11893  ethyl 8-hydroxy-alpha-(2-propynylamino)-5-quin...
# 11894  High Potency Multivitamins & Minerals Caplets|...
# 11895  Sofracort Eye/ear Drops|dexamethasone metasulf...
# 11896                                            ribitol
# 11897                                        ceramide ap
# 11898                                        ceramide ng
# 11900                                    tosylchloramide
# 11906                                       tenivastatin
# 11907                                          cinazepam
# 11908                                         clonazolam
# 11909                                         nitrazolam
# 11910                                          pyrazolam
# 11911                                         bentazepam
# 11912                                        brovanexine
# 11913                                            mk-1454
# 11914                                           adu-s100
# 11915                             Vitrakvi|larotrectinib
# 11917  Mandol Inj 1gm/amp|Mandol Inj 2gm/amp|cefamand...
# 11918                                         dabigatran
# 11919             Aronamin Gold|riboflavin tetrabutyrate
# 11920                                            mebenil
# 11921                                       rebeccamycin
#
# [10254 rows x 9 columns]

# %%
drugbank_df[drugbank_df.patents!=""].shape
# Out:
# (1006, 9)
