# %%
import xml.etree.ElementTree as ET
import collections
import pandas as pd
import itertools

# %%
xml_file = "full database.xml"
tree = ET.parse(xml_file)

# %%
root = tree.getroot()

# %%
def collapse_list_values(row):
    for key, value in row.items():
        if isinstance(value, list):
            row[key] = '|'.join(value)
    return row

# %%
drugbank_df = pd.DataFrame(columns=["drugbank_id", "name", "type", "approved", "products", 
                                "indication", "inchikey", "chembl_id","patent_number", "patent_country", "patent_date"])

# %%
ns = '{http://www.drugbank.ca}'
inchikey_template = "{ns}calculated-properties/{ns}property[{ns}kind='InChIKey']/{ns}value"
chembl_id_template = "{ns}external-identifiers/{ns}external-identifier[{ns}resource='ChEMBL']/{ns}identifier"

for i, drug in enumerate(root):
    #row = collections.OrderedDict()
    row = dict()
    assert drug.tag == ns + 'drug'
    row['drugbank_id'] = drug.findtext(ns + "drugbank-id[@primary='true']")
    row['name'] = drug.findtext(ns + "name").lower()
    row['type'] = drug.get('type')    
    # check if approved
    groups = [group.text for group in
        drug.findall("{ns}groups/{ns}group".format(ns = ns))]
    if "approved" in groups:
        row["approved"] = True
    else:
        row["approved"] = False
    row['indication'] = drug.findtext(ns + "indication")
    #row['target'] = [group.text for group in
    #    drug.findall("{ns}targets/{ns}target/{ns}name".format(ns = ns))]
    #row['categories'] = [x.findtext(ns + 'category') for x in
    #    drug.findall("{ns}categories/{ns}category".format(ns = ns))]
    row['inchikey'] = drug.findtext(inchikey_template.format(ns = ns))
    row['chembl_id'] = drug.findtext(chembl_id_template.format(ns = ns))
    patents = [group.text for group in
        drug.findall("{ns}patents/{ns}patent/{ns}number".format(ns = ns))]
    patent_countries = [group.text for group in
        drug.findall("{ns}patents/{ns}patent/{ns}country".format(ns = ns))]
    patent_dates = [group.text for group in
        drug.findall("{ns}patents/{ns}patent/{ns}approved".format(ns = ns))]
    
    aliases = {
        elem.text.lower() for elem in 
        drug.findall("{ns}products/{ns}product/{ns}name".format(ns = ns))
    }
    aliases.add(row['name'])
    aliases = sorted(aliases)
    aliases_str = '|'.join(aliases)
    row['products'] = aliases_str
    
    for patent, country, date in zip(patents, patent_countries, patent_dates):
        row["patent_number"] = patent
        row["patent_country"] = country
        row["patent_date"] = date
        drugbank_df = drugbank_df.append(row, ignore_index=True)

# %%
drugbank_df
# Out:
#      drugbank_id                    name            type approved  \
# 0        DB00001               lepirudin         biotech     True
# 1        DB00002               cetuximab         biotech     True
# 2        DB00003            dornase alfa         biotech     True
# 3        DB00003            dornase alfa         biotech     True
# 4        DB00005              etanercept         biotech     True
# 5        DB00005              etanercept         biotech     True
# 6        DB00005              etanercept         biotech     True
# 7        DB00006             bivalirudin  small molecule     True
# 8        DB00006             bivalirudin  small molecule     True
# 9        DB00006             bivalirudin  small molecule     True
# 10       DB00006             bivalirudin  small molecule     True
# 11       DB00007              leuprolide         biotech     True
# 12       DB00007              leuprolide         biotech     True
# 13       DB00007              leuprolide         biotech     True
# 14       DB00007              leuprolide         biotech     True
# 15       DB00007              leuprolide         biotech     True
# 16       DB00007              leuprolide         biotech     True
# 17       DB00007              leuprolide         biotech     True
# 18       DB00007              leuprolide         biotech     True
# 19       DB00007              leuprolide         biotech     True
# 20       DB00007              leuprolide         biotech     True
# 21       DB00007              leuprolide         biotech     True
# 22       DB00007              leuprolide         biotech     True
# 23       DB00007              leuprolide         biotech     True
# 24       DB00007              leuprolide         biotech     True
# 25       DB00007              leuprolide         biotech     True
# 26       DB00007              leuprolide         biotech     True
# 27       DB00007              leuprolide         biotech     True
# 28       DB00007              leuprolide         biotech     True
# 29       DB00007              leuprolide         biotech     True
# ...          ...                     ...             ...      ...
# 7433     DB14554                dotatate  small molecule     True
# 7434     DB14568              ivosidenib  small molecule     True
# 7435     DB14568              ivosidenib  small molecule     True
# 7436     DB14568              ivosidenib  small molecule     True
# 7437     DB14582               patisiran         biotech     True
# 7438     DB14582               patisiran         biotech     True
# 7439     DB14582               patisiran         biotech     True
# 7440     DB14582               patisiran         biotech     True
# 7441     DB14582               patisiran         biotech     True
# 7442     DB14582               patisiran         biotech     True
# 7443     DB14582               patisiran         biotech     True
# 7444     DB14582               patisiran         biotech     True
# 7445     DB14582               patisiran         biotech     True
# 7446     DB14582               patisiran         biotech     True
# 7447     DB14582               patisiran         biotech     True
# 7448     DB14582               patisiran         biotech     True
# 7449     DB14582               patisiran         biotech     True
# 7450     DB14582               patisiran         biotech     True
# 7451     DB14582               patisiran         biotech     True
# 7452     DB14582               patisiran         biotech     True
# 7453     DB14582               patisiran         biotech     True
# 7454     DB14582               patisiran         biotech     True
# 7455     DB14582               patisiran         biotech     True
# 7456     DB14582               patisiran         biotech     True
# 7457     DB14582               patisiran         biotech     True
# 7458     DB14631  prednisolone phosphate  small molecule     True
# 7459     DB14631  prednisolone phosphate  small molecule     True
# 7460     DB14631  prednisolone phosphate  small molecule     True
# 7461     DB14695     ferric oxyhydroxide  small molecule     True
# 7462     DB14695     ferric oxyhydroxide  small molecule     True
#
#                                                products  \
# 0                                    lepirudin|refludan
# 1                                     cetuximab|erbitux
# 2               dornase alfa|pulmozyme|pulmozyme 1mg/ml
# 3               dornase alfa|pulmozyme|pulmozyme 1mg/ml
# 4                      brenzys|enbrel|erelzi|etanercept
# 5                      brenzys|enbrel|erelzi|etanercept
# 6                      brenzys|enbrel|erelzi|etanercept
# 7     angiomax|bivalirudin|bivalirudin for injection...
# 8     angiomax|bivalirudin|bivalirudin for injection...
# 9     angiomax|bivalirudin|bivalirudin for injection...
# 10    angiomax|bivalirudin|bivalirudin for injection...
# 11    eligard|eligard 22.5mg|eligard 30 mg|eligard 4...
# 12    eligard|eligard 22.5mg|eligard 30 mg|eligard 4...
# 13    eligard|eligard 22.5mg|eligard 30 mg|eligard 4...
# 14    eligard|eligard 22.5mg|eligard 30 mg|eligard 4...
# 15    eligard|eligard 22.5mg|eligard 30 mg|eligard 4...
# 16    eligard|eligard 22.5mg|eligard 30 mg|eligard 4...
# 17    eligard|eligard 22.5mg|eligard 30 mg|eligard 4...
# 18    eligard|eligard 22.5mg|eligard 30 mg|eligard 4...
# 19    eligard|eligard 22.5mg|eligard 30 mg|eligard 4...
# 20    eligard|eligard 22.5mg|eligard 30 mg|eligard 4...
# 21    eligard|eligard 22.5mg|eligard 30 mg|eligard 4...
# 22    eligard|eligard 22.5mg|eligard 30 mg|eligard 4...
# 23    eligard|eligard 22.5mg|eligard 30 mg|eligard 4...
# 24    eligard|eligard 22.5mg|eligard 30 mg|eligard 4...
# 25    eligard|eligard 22.5mg|eligard 30 mg|eligard 4...
# 26    eligard|eligard 22.5mg|eligard 30 mg|eligard 4...
# 27    eligard|eligard 22.5mg|eligard 30 mg|eligard 4...
# 28    eligard|eligard 22.5mg|eligard 30 mg|eligard 4...
# 29    eligard|eligard 22.5mg|eligard 30 mg|eligard 4...
# ...                                                 ...
# 7433                                   dotatate|netspot
# 7434                                 ivosidenib|tibsovo
# 7435                                 ivosidenib|tibsovo
# 7436                                 ivosidenib|tibsovo
# 7437                                 onpattro|patisiran
# 7438                                 onpattro|patisiran
# 7439                                 onpattro|patisiran
# 7440                                 onpattro|patisiran
# 7441                                 onpattro|patisiran
# 7442                                 onpattro|patisiran
# 7443                                 onpattro|patisiran
# 7444                                 onpattro|patisiran
# 7445                                 onpattro|patisiran
# 7446                                 onpattro|patisiran
# 7447                                 onpattro|patisiran
# 7459
# 7460
# 7461
# 7462
#
#                          inchikey      chembl_id patent_number patent_country  \
# 0                            None  CHEMBL1201666       5180668  United States
# 1                            None  CHEMBL1201577       1340417         Canada
# 2                            None  CHEMBL1201431       2184581         Canada
# 3                            None  CHEMBL1201431       2137237         Canada
# 4                            None  CHEMBL1201572       2476934         Canada
# 5                            None  CHEMBL1201572       2123593         Canada
# 6                            None  CHEMBL1201572       7276477  United States
# 7     OIRCOABEOLEUMC-GEJPAHFPSA-N  CHEMBL2103749       5196404  United States
# 8     OIRCOABEOLEUMC-GEJPAHFPSA-N  CHEMBL2103749       2065150         Canada
# 9     OIRCOABEOLEUMC-GEJPAHFPSA-N  CHEMBL2103749       7598343  United States
# 10    OIRCOABEOLEUMC-GEJPAHFPSA-N  CHEMBL2103749       7582727  United States
# 11                           None  CHEMBL1201199       6036976  United States
# 12                           None  CHEMBL1201199       8921326  United States
# 13                           None  CHEMBL1201199       7429559  United States
# 14                           None  CHEMBL1201199       8815801  United States
# 15                           None  CHEMBL1201199       5728396  United States
# 16                           None  CHEMBL1201199       6156331  United States
# 17                           None  CHEMBL1201199       6375978  United States
# 18                           None  CHEMBL1201199       6235712  United States
# 19                           None  CHEMBL1201199       6113938  United States
# 20                           None  CHEMBL1201199       6124261  United States
# 21                           None  CHEMBL1201199       6395292  United States
# 22                           None  CHEMBL1201199       6132420  United States
# 23                           None  CHEMBL1201199       5985305  United States
# 24                           None  CHEMBL1201199       5932547  United States
# 25                           None  CHEMBL1201199       6565874  United States
# 26                           None  CHEMBL1201199       6773714  United States
# 27                           None  CHEMBL1201199       6626870  United States
# 28                           None  CHEMBL1201199       9283282  United States
# 29                           None  CHEMBL1201199       9254307  United States
# ...                           ...            ...           ...            ...
# 7433  QVFLVLMYXXNJDT-RVXLOKAISA-N           None       9375498  United States
# 7434  WIJZXSAJMHAVGX-DHLKQENFSA-N  CHEMBL3989958       9474779  United States
# 7435  WIJZXSAJMHAVGX-DHLKQENFSA-N  CHEMBL3989958       9850277  United States
# 7436  WIJZXSAJMHAVGX-DHLKQENFSA-N  CHEMBL3989958       9968595  United States
# 7437                         None           None       8802644  United States
# 7438                         None           None       8778902  United States
# 7439                         None           None       9234196  United States
# 7440                         None           None       8822668  United States
# 7441                         None           None       9364435  United States
# 7442                         None           None       8158601  United States
# 7443                         None           None       8741866  United States
# 7444                         None           None       8168775  United States
# 7445                         None           None       9193753  United States
# 7446                         None           None       8334373  United States
# 7447                         None           None       8058069  United States
# 7448                         None           None       8492359  United States
# 7449                         None           None       8642076  United States
# 7450                         None           None       8362231  United States
# 7451                         None           None       8895718  United States
# 7452                         None           None       8552171  United States
# 7453                         None           None       8372968  United States
# 7454                         None           None       9943538  United States
# 7455                         None           None       9943539  United States
# 7456                         None           None       9567582  United States
# 7457                         None           None       8895721  United States
# 7458  JDOZJEUDSLGTLU-VWUMJDOOSA-N  CHEMBL1201231       6221392  United States
# 7459  JDOZJEUDSLGTLU-VWUMJDOOSA-N  CHEMBL1201231       6024981  United States
# 7460  JDOZJEUDSLGTLU-VWUMJDOOSA-N  CHEMBL1201231       6740341  United States
# 7461  IEECXTSVVFWGSE-UHFFFAOYSA-M           None       6174442  United States
# 7462  IEECXTSVVFWGSE-UHFFFAOYSA-M           None       9561251  United States
#
#      patent_date
# 0     1993-01-19
# 1     1999-03-02
# 2     2005-02-22
# 3     2004-10-26
# 4     2009-06-16
# 5     2000-03-14
# 6     2007-10-02
# 7     1993-03-23
# 8     1999-12-14
# 9     2009-10-06
# 10    2009-09-01
# 11    2000-03-14
# 12    2014-12-30
# 13    2008-09-30
# 14    2014-08-26
# 15    1998-03-17
# 16    2000-12-05
# 17    2002-04-23
# 18    2001-05-22
# 19    2000-09-05
# 20    2000-09-26
# 21    2002-05-28
# 22    2000-10-17
# 23    1999-11-16
# 24    1999-08-03
# 25    2003-05-20
# 26    2004-08-10
# 27    2003-09-30
# 28    2016-03-15
# 29    2016-02-09
# ...          ...
# 7433  2016-06-28
# 7434  2016-10-25
# 7435  2017-12-26
# 7436  2018-05-15
# 7437  2014-08-12
# 7438  2014-07-15
# 7439  2016-01-12
# 7440  2014-09-02
# 7441  2016-06-14
# 7442  2012-04-17
# 7443  2014-06-03
# 7444  2012-05-01
# 7445  2015-11-24
# 7446  2012-12-18
# 7447  2011-11-15
# 7448  2013-07-23
# 7449  2014-02-04
# 7450  2013-01-29
# 7451  2014-11-25
# 7452  2013-10-08
# 7453  2013-02-12
# 7454  2018-04-17
# 7455  2018-04-17
# 7456  2017-02-14
# 7457  2014-11-25
# 7458  2001-04-24
# 7459  2000-02-15
# 7460  2004-05-25
# 7461  2001-01-16
# 7462  2017-02-07
#
# [7463 rows x 11 columns]

# %%
drugbank_df.drugbank_id.nunique()
# Out:
# 1006

# %%
drugbank_df.patent_country.nunique()
# Out:
# 2

# %%
drugbank_df.loc[(~drugbank_df.inchikey.isnull()) & (drugbank_df.chembl_id.isnull())]
# Out:
#      drugbank_id                                               name  \
# 414      DB00185                                         cevimeline
# 415      DB00185                                         cevimeline
# 561      DB00225                                        gadodiamide
# 562      DB00225                                        gadodiamide
# 563      DB00225                                        gadodiamide
# 2323     DB00686                               pentosan polysulfate
# 4668     DB01345                                   potassium cation
# 4804     DB01592                                               iron
# 5284     DB06215                                        ferumoxytol
# 5285     DB06215                                        ferumoxytol
# 5286     DB06215                                        ferumoxytol
# 5287     DB06215                                        ferumoxytol
# 5288     DB06215                                        ferumoxytol
# 5289     DB06215                                        ferumoxytol
# 6646     DB09147                               ferric pyrophosphate
# 6647     DB09147                               ferric pyrophosphate
# 6648     DB09147                               ferric pyrophosphate
# 6760     DB09275                       bismuth subcitrate potassium
# 6905     DB09490                             indium in-111 chloride
# 6906     DB09490                             indium in-111 chloride
# 6989     DB11284                 dl-dimyristoylphosphatidylglycerol
# 7119     DB11835                        indium in-111 pentetreotide
# 7120     DB11835                        indium in-111 pentetreotide
# 7212     DB12161                                   deutetrabenazine
# 7213     DB12161                                   deutetrabenazine
# 7214     DB12161                                   deutetrabenazine
# 7215     DB12161                                   deutetrabenazine
# 7216     DB12161                                   deutetrabenazine
# 7313     DB13925                             dotatate gallium ga-68
# 7332     DB13931                                         netarsudil
# 7333     DB13931                                         netarsudil
# 7334     DB13931                                         netarsudil
# 7335     DB13931                                         netarsudil
# 7336     DB13931                                         netarsudil
# 7339     DB13949                                      ferric cation
# 7340     DB13949                                      ferric cation
# 7341     DB13949                                      ferric cation
# 7342     DB13949                                      ferric cation
# 7343     DB13949                                      ferric cation
# 7344     DB13949                                      ferric cation
# 7345     DB13949                                      ferric cation
# 7346     DB13949                                      ferric cation
# 7347     DB13949                                      ferric cation
# 7348     DB13949                                      ferric cation
# 7349     DB13949                                      ferric cation
# 7350     DB13949                                      ferric cation
# 7351     DB13949                                      ferric cation
# 7352     DB13949                                      ferric cation
# 7371     DB14048                     sodium zirconium cyclosilicate
# 7372     DB14048                     sodium zirconium cyclosilicate
# 7373     DB14048                     sodium zirconium cyclosilicate
# 7374     DB14048                     sodium zirconium cyclosilicate
# 7375     DB14048                     sodium zirconium cyclosilicate
# 7376     DB14048                     sodium zirconium cyclosilicate
# 7377     DB14048                     sodium zirconium cyclosilicate
# 7379     DB14105  sodium 1,2-dipalmitoyl-sn-glycero-3-phospho-(1...
# 7433     DB14554                                           dotatate
# 7461     DB14695                                ferric oxyhydroxide
# 7462     DB14695                                ferric oxyhydroxide
#
#                 type approved  \
# 414   small molecule     True
# 415   small molecule     True
# 561   small molecule     True
# 562   small molecule     True
# 563   small molecule     True
# 2323  small molecule     True
# 4668  small molecule     True
# 4804  small molecule     True
# 5284  small molecule     True
# 5285  small molecule     True
# 5286  small molecule     True
# 5287  small molecule     True
# 5288  small molecule     True
# 5289  small molecule     True
# 6646  small molecule    False
# 6647  small molecule    False
# 6648  small molecule    False
# 6760  small molecule     True
# 6905  small molecule     True
# 6906  small molecule     True
# 6989  small molecule     True
# 7119  small molecule     True
# 7120  small molecule     True
# 7212  small molecule     True
# 7213  small molecule     True
# 7214  small molecule     True
# 7215  small molecule     True
# 7216  small molecule     True
# 7313  small molecule     True
# 7332  small molecule     True
# 7333  small molecule     True
# 7334  small molecule     True
# 7335  small molecule     True
# 7336  small molecule     True
# 7339  small molecule     True
# 7340  small molecule     True
# 7341  small molecule     True
# 7342  small molecule     True
# 7343  small molecule     True
# 7344  small molecule     True
# 7345  small molecule     True
# 7346  small molecule     True
# 7347  small molecule     True
# 7348  small molecule     True
# 7349  small molecule     True
# 7350  small molecule     True
# 7351  small molecule     True
# 7352  small molecule     True
# 7371  small molecule     True
# 7372  small molecule     True
# 7373  small molecule     True
# 7374  small molecule     True
# 7375  small molecule     True
# 7376  small molecule     True
# 7377  small molecule     True
# 7379  small molecule     True
# 7433  small molecule     True
# 7461  small molecule     True
# 7462  small molecule     True
#
#                                                products  \
# 414          cevimeline|cevimeline hydrochloride|evoxac
# 415          cevimeline|cevimeline hydrochloride|evoxac
# 561       gadodiamide|omniscan|omniscan liq iv 287mg/ml
# 562       gadodiamide|omniscan|omniscan liq iv 287mg/ml
# 563       gadodiamide|omniscan|omniscan liq iv 287mg/ml
# 2323                       elmiron|pentosan polysulfate
# 4668               potassium cation|rurina|telom-x-gene
# 4804  active fe|active ob|actyform|advanced b & t fo...
# 5284                       feraheme|feridex|ferumoxytol
# 5285                       feraheme|feridex|ferumoxytol
# 5286                       feraheme|feridex|ferumoxytol
# 5287                       feraheme|feridex|ferumoxytol
# 5288                       feraheme|feridex|ferumoxytol
# 5289                       feraheme|feridex|ferumoxytol
# 6646  escavite lq|ferric pyrophosphate|tricare prena...
# 6647  escavite lq|ferric pyrophosphate|tricare prena...
# 6648  escavite lq|ferric pyrophosphate|tricare prena...
# 6760                bismuth subcitrate potassium|pylera
# 6905  indiclor|indium in 111 chloride|indium in-111 ...
# 6906  indiclor|indium in 111 chloride|indium in-111 ...
# 6989         abelcet|dl-dimyristoylphosphatidylglycerol
# 7119             indium in-111 pentetreotide|octreoscan
# 7120             indium in-111 pentetreotide|octreoscan
# 7212                           austedo|deutetrabenazine
# 7213                           austedo|deutetrabenazine
# 7214                           austedo|deutetrabenazine
# 7215                           austedo|deutetrabenazine
# 7216                           austedo|deutetrabenazine
# 7313                             dotatate gallium ga-68
# 7332                               netarsudil|rhopressa
# 7333                               netarsudil|rhopressa
# 7334                               netarsudil|rhopressa
# 7335                               netarsudil|rhopressa
# 7336                               netarsudil|rhopressa
# 7339                                      ferric cation
# 7340                                      ferric cation
# 7341                                      ferric cation
# 7342                                      ferric cation
# 7343                                      ferric cation
# 7344                                      ferric cation
# 7345                                      ferric cation
# 7346                                      ferric cation
# 7347                                      ferric cation
# 7348                                      ferric cation
# 7349                                      ferric cation
# 7350                                      ferric cation
# 7351                                      ferric cation
# 7352                                      ferric cation
# 7371             lokelma|sodium zirconium cyclosilicate
# 7372             lokelma|sodium zirconium cyclosilicate
# 7373             lokelma|sodium zirconium cyclosilicate
# 7374             lokelma|sodium zirconium cyclosilicate
# 7375             lokelma|sodium zirconium cyclosilicate
# 7376             lokelma|sodium zirconium cyclosilicate
# 7377             lokelma|sodium zirconium cyclosilicate
# 7379  lumason|sodium 1,2-dipalmitoyl-sn-glycero-3-ph...
# 7433                                   dotatate|netspot
# 7461                       ferric oxyhydroxide|velphoro
# 7462                       ferric oxyhydroxide|velphoro
#
#                                              indication  \
# 414   For the treatment of symptoms of dry mouth in ...
# 415   For the treatment of symptoms of dry mouth in ...
# 561   For intravenous use in MRI to visualize lesion...
# 562   For intravenous use in MRI to visualize lesion...
# 563   For intravenous use in MRI to visualize lesion...
# 2323  For the relief of bladder pain or discomfort a...
# 4668  Potassium is used to regulate hypokalemia as a...
# 4804  Used in preventing and treating iron-deficienc...
# 5284  This drug is indicated for the treatment of ir...
# 5285  This drug is indicated for the treatment of ir...
# 5286  This drug is indicated for the treatment of ir...
# 5287  This drug is indicated for the treatment of ir...
# 5288  This drug is indicated for the treatment of ir...
# 5289  This drug is indicated for the treatment of ir...
# 6646  Ferric pyrophosphate is intended to be indicat...
# 6647  Ferric pyrophosphate is intended to be indicat...
# 6648  Ferric pyrophosphate is intended to be indicat...
# 6760  For the treatment of peptic ulcer and gastro-o...
# 6905  Indium In-111 Chloride is indicated for radio ...
# 6906  Indium In-111 Chloride is indicated for radio ...
# 6989  DL-dimyristoylphosphatidylglycerol is not an c...
# 7119
# 7120
# 7212  Indicated for the treatment of chorea associat...
# 7213  Indicated for the treatment of chorea associat...
# 7214  Indicated for the treatment of chorea associat...
#
#      patent_date
# 414   1994-08-23
# 415   1989-08-08
# 561   1996-10-01
# 562   1994-11-08
# 563   1995-06-06
# 2323  1993-01-19
# 4668  2005-09-20
# 4804  2003-12-23
# 5284  2013-08-06
# 5285  2013-11-26
# 5286  2003-07-29
# 5287  2009-06-30
# 5288  2011-01-18
# 5289  2015-01-06
# 6646  2004-08-24
# 6647  2010-10-19
# 6648  2004-02-10
# 6760  2002-02-26
# 6905  2000-09-26
# 6906  1998-07-07
# 6989  2002-06-18
# 7119  2000-09-26
# 7120  1998-07-07
# 7212  2013-09-03
# 7213  2016-03-29
# 7214  2016-01-12
# 7215  2017-01-24
# 7216  2017-11-14
# 7313  2016-06-28
# 7332  2013-03-12
# 7333  2015-08-04
# 7334  2013-05-28
# 7335  2016-08-16
# 7336  2018-04-03
# 7339  2014-09-30
# 7340  2012-01-10
# 7341  1998-05-19
# 7342  2012-12-25
# 7343  2015-06-09
# 7344  2014-12-02
# 7345  2014-06-17
# 7346  2010-08-03
# 7347  2014-06-17
# 7348  2013-12-17
# 7349  2012-10-30
# 7350  2016-07-12
# 7351  2016-05-03
# 7352  2017-09-12
# 7371  2017-03-14
# 7372  2014-08-19
# 7373  2017-12-19
# 7374  2018-01-09
# 7375  2001-12-25
# 7376  2014-11-04
# 7377  2014-08-12
# 7379  1997-11-11
# 7433  2016-06-28
# 7461  2001-01-16
# 7462  2017-02-07

# %%
drugbank_df.loc[(~drugbank_df.inchikey.isnull()) | (~drugbank_df.chembl_id.isnull())].patent_number.nunique()
# Out:
# 2

# %%
drugbank_df.approved.unique()
# Out:
# array([True, False], dtype=object)

# %%
drugbank_df.patent_number.nunique()
# Out:
# 5616

# %%
drugbank_df.to_csv("drugbank_df.csv", sep='\t', index=False)

# %%
drugbank_df = pd.read_csv("drugbank_df.csv", sep='\t')

# %%
drugbank_df.shape
# Out:
# (7463, 11)

# %%
hiv_list = ["nelfinavir", "efavirenz", "lamivudine", "zidovudine", "latanoprost", "ritonavir",
           "didanosine", "nevirapine", "stavudine", "lopinavir", "viramune", "3TC", "ledipasvir", 
           "sofosbuvir", "nexavar", "triAvir", "gleevic", "viread", "kaletra", "indinavir", "abacavir"]

# %%
hiv_df = pd.DataFrame(columns=drugbank_df.columns)
for drug in hiv_list:
    drug_df = drugbank_df.loc[drugbank_df.products.str.contains(drug)]
    print(drug_df.shape)
    hiv_df = hiv_df.append(drug_df)
# Out:
# (2, 11)
# (100, 11)
# (33, 11)
# (33, 11)
# (25, 11)
# (59, 11)
# (3, 11)
# (23, 11)
# (1, 11)
# (59, 11)
# (3, 11)
# (0, 11)
# (40, 11)
# (56, 11)
# (10, 11)
# (0, 11)
# (0, 11)
# (33, 11)
# (59, 11)
# (4, 11)
# (30, 11)

# %%
def get_cc(country):
    if country == "United States":
        return "US"
    if country == "Canada":
        return "CA"
hiv_df["country_code"] = hiv_df["patent_country"].apply(lambda x: get_cc(x))

# %%
hiv_df["publication_number"] = hiv_df["country_code"] + "-" + hiv_df["patent_number"]

# %%
hiv_df.to_csv("drugbank_hiv_list.csv", sep="\t", index=False)
